# %% [raw]
#  #%%
# import numpy as np
# import matplotlib.pyplot as plt

# %%
# Schwwarzschild effective potential
def V_sc(r, sigma, G=1, M=10, L=10):
    return 1/2 * sigma - sigma * G * M / r + L**2 / (2 * r**2)  - G * M * L**2 / r**3

# %%
r = np.linspace(2, 10, 1000)
V_sc(r, sigma=1)
# Out:
# array([-117.        , -115.59000469, -114.20255771, -112.8372114 ,
#        -111.49352866, -110.17108274, -108.86945689, -107.58824413,
#        -106.32704695, -105.08547711, -103.86315531, -102.65971103,
#        -101.47478224, -100.30801518,  -99.15906419,  -98.02759142,
#         -96.91326668,  -95.81576722,  -94.73477755,  -93.66998921,
#         -92.62110063,  -91.58781694,  -90.5698498 ,  -89.5669172 ,
#         -88.57874335,  -87.60505848,  -86.64559872,  -85.70010592,
#         -84.76832752,  -83.85001642,  -82.94493081,  -82.05283409,
#         -81.17349468,  -80.30668596,  -79.45218607,  -78.60977788,
#         -77.7792488 ,  -76.96039072,  -76.15299987,  -75.35687672,
#         -74.5718259 ,  -73.79765606,  -73.03417981,  -72.28121362,
#         -71.53857769,  -70.80609593,  -70.08359579,  -69.37090824,
#         -68.66786768,  -67.97431182,  -67.29008163,  -66.61502128,
#         -65.94897804,  -65.29180221,  -64.64334705,  -64.00346874,
# ...

# %%
r = np.linspace(2, 30, 1000)

for L_M in np.linspace(0.5, 5, 5):
    plt.plot(r, V_sc(r, sigma=0, G=1,M=1,L=L_M), label=f"L/M={L_M}")
    # plt.yscale("log")
plt.axvline(3,ymin=0.03,ls="--",c="k", label="3GM")
plt.axvline(2, ymin=0.03, ls="-.", c="k", label="Event horizon")
plt.legend()
plt.xlabel("r")
plt.ylabel("Veff")
plt.title("Effective potetnial for massless particle")
plt.show()

# %%
for L_M in np.linspace(3, 4, 8):
    plt.plot(r, V_sc(r, sigma=1, G=1, M=1, L=L_M), label=f"L/M={L_M:.2f}")
# L_M = 10
# plt.plot(r, V_sc(r, sigma=1, G=1, M=1, L=L_M), label=f"L/M={L_M:.2f}")
plt.legend()
plt.xlabel("r")
plt.ylabel("Veff")
plt.ylim(-0.1, 0.51)
plt.xlim(0, 35)
plt.title("Effective potential for massive particle")
plt.show()

# %% [markdown]
# # Kerr space-time

# %%
# Kerr effective potential for massive particle
def V_kerr(r, a, G=1, M=1, l=1, e=1):
    return -M/r  + (l**2 - a**2 * (e**2 - 1)) / (2*r**2) - M *(l-a*e)**2 / r**3

# %%
# r = np.linspace(2, 30, 1000)



for L_M in np.linspace(3, 4, 8):
    plt.plot(r, V_kerr(r, 1, G=1, M=1, l=L_M), label=f"L/M={L_M:.2f}")
# L_M = 10
# plt.plot(r, V_sc(r, sigma=1, G=1, M=1, L=L_M), label=f"L/M={L_M:.2f}")
plt.legend()
plt.xlabel("r")
plt.ylabel("Veff")
plt.ylim(-0.15, 0.01)
plt.xlim(2, 35)
plt.title("Effective potential for massive particle")
plt.show()

# %%
r = np.linspace(2, 35, 100)

fig, axs = plt.subplots(nrows=2, ncols=5, figsize=(16, 8.))

for i, a in enumerate(np.linspace(0, 0.8, 5)):
    for L_M in np.linspace(3, 4, 8):
        axs[0][i].plot(r, V_kerr(r, a, G=1, M=1, l=L_M), label=f"L/M={L_M:.2f}")  
    
    axs[0][i].axvline(2, ls="--", c="k")
    axs[0][i].set_title(f"a={a:.1f}")
    axs[0][i].set_xlabel("r")
    axs[0][i].set_ylabel("Veff")
    axs[0][i].set_ylim(-0.1, 0.15)
    axs[0][i].set_xlim(0.5, 35)

for i, a in enumerate(np.linspace(-0.2, -1.0, 5)):
    for L_M in np.linspace(3, 4, 8):
        axs[1][i].plot(r, V_kerr(r, a, G=1, M=1, l=L_M), label=f"L/M={L_M:.2f}")  
    
    axs[1][i].axvline(2, ls="--", c="k")
    axs[1][i].set_title(f"a={a:.1f}")
    axs[1][i].set_xlabel("r")
    axs[1][i].set_ylabel("Veff")
    axs[1][i].set_ylim(-0.1, 0.0)
    axs[1][i].set_xlim(0.5, 35)

plt.suptitle("Effective potential for Kerr black hole (Massive particles orbiting equator)")
plt.show()

# %%
r = np.linspace(2, 35, 100)

fig, axs = plt.subplots(nrows=1, ncols=5, figsize=(20, 5))

for i, a in enumerate(np.linspace(-0.2, -1.0, 5)):
    for L_M in np.linspace(3, 4, 8):
        axs[i].plot(r, V_kerr(r, a, G=1, M=1, l=L_M), label=f"L/M={L_M:.2f}")  
    
    axs[i].axvline(2, ls="--", c="k")
    axs[i].set_title(f"a={a:.1f}")
    axs[i].set_xlabel("r")
    axs[i].set_ylabel("Veff")
    axs[i].set_ylim(-0.2, 0.2)
    axs[i].set_xlim(0.5, 35)

plt.suptitle("Effective potential for Kerr black hole with varying a")
plt.show()

# %%
def W_kl(r, a, G=1, M=1, b=1, sigma=1):
    return 1/(r**2) * (1 - (a/b)**2 - 2*M/r * (1 - sigma * (a/b))**2)

# %%
r = np.linspace(2, 35, 10000)

fig, axs = plt.subplots(nrows=1, ncols=5, figsize=(20, 5))

for i, a in enumerate(np.linspace(0.0, 1.0, 5)):
    for L_M in np.linspace(3, 4, 8):
        axs[i].plot(r, W_kl(r, a, G=1, M=1, b=L_M, sigma = np.abs(L_M)/L_M), label=f"L/M={L_M:.2f}")

    axs[i].axvline(2, ls="--", c="k")
    axs[i].set_title(f"a={a:.1f}")
    axs[i].set_xlabel("r")
    axs[i].set_ylabel("Veff")
    axs[i].set_ylim(0, 0.1)
    axs[i].set_xlim(0.5, 10)

plt.suptitle("Effective potential for Kerr black hole (massless orbits)")
plt.show()

# %% [markdown]
# ## Particle orbits

# %%
def rn(rp, rpp, dt, G=1, M=1, L=1):
    """Implementing reccurence relation for r DE"""
    Fg = -G * M / rp**2
    l1 = L**2 / rp**3   # Meaingless variable name
    F2 = - G * M * L**2 / rp**4
    return 2*rp - rpp + dt**2 * (Fg + l1 + F2)

def phin(phip, rn, rp, dt, L=1):
    """Implementing reccurence relation for phi DE"""
    return phip + dt * L / (0.5 * (rn + rp)**2)

# %%
G = 1
M = 1

dtau = 0.001
L = 2 * np.sqrt(3) * G * M

r0 = 6 * G * M
r1 = r0
# r1 = r0
phi0 = 0
phi1 = phi0 + L**2 / (r0**2) * dtau
# phi1 = phi0
iterations = 50000

rs = np.zeros(iterations)
phis = np.zeros(iterations)

rs[0], rs[1] = r0, r1
phis[0], phis[1] = phi0, phi1

rpp = r0
rp = r1
r = rp
phip, phi = phi1, phi1
for index in range(iterations):
    # Initialise previous values
    rp, rpp = r, rp
    phip = phi

    r = rn(rp, rpp, dtau, M = M, G=G)
    phi = phin(phip, r, rp, dtau, L=L)

    rs[index] = r
    phis[index] = phi
# Out:
# (-6.0, 6.0)

# %%
plt.scatter(rs * np.cos(phis), rs * np.sin(phis), s=0.1)
plt.xlim(-r0, r0)
plt.ylim(-r0, r0)

# %%
# Out:
# C:\Users\jmonc\AppData\Local\Temp\ipykernel_14384\4039650984.py:5: RuntimeWarning: invalid value encountered in sqrt
#   return - np.sqrt(E**2 - sigma * (1 - 2*rs / r) +L**2 / (2*r**2) + G * M * L**2 / r**3)
# C:\Users\jmonc\hon_code\venv\lib\site-packages\scipy\integrate\_odepack_py.py:248: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %%
from scipy.integrate import odeint

def dr_dtau(r, sigma, G, M, L):
    rs = 2 * G * M
    return - np.sqrt(E**2 - sigma * (1 - 2*rs / r) +L**2 / (2*r**2) + G * M * L**2 / r**3)

def dphi_dtay(r, L):
    return L / (r**2)

def schwarzschild_orbit(y, t, sigma, G, M, L):
    r, phi = y
    return [dr_dtau(r, sigma, G, M, L), dphi_dtay(r, L)]

# initial conditions
r0 = 10
phi0 = 0
y0 = [r0, phi0]

# time span
t_span = np.linspace(0, 100, 1000)

# constants
sigma = 1
G = 1
M = 1
L = 1

# solve the differential equations
sol = odeint(schwarzschild_orbit, y0, t_span, args=(sigma, G, M, L))

# extract the results
r = sol[:, 0]
phi = sol[:, 1]

# plot results
plt.plot(r * np.cos(phi), r * np.sin(phi))
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[276], line 36
#      33 M = 1
#      35 # solve the differential equations
# ---> 36 sol = odeint(schwarzschild_orbit, y0, t_span, args=(G, M))
#      38 # extract the results
#      39 r = sol[:, 0]
#
# File ~\hon_code\venv\lib\site-packages\scipy\integrate\_odepack_py.py:242, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     240 t = copy(t)
#     241 y0 = copy(y0)
# --> 242 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     243                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     244                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     245                          int(bool(tfirst)))
#     246 if output[-1] < 0:
# ...

# %%
import numpy as np
from scipy.integrate import odeint

G = 1
M = 1
L = 2 * np.sqrt(3) * G * M
E = 0
sigma = 1

def schwarzschild_orbit(y, t, G, M):
    r, phi, dr_dt, dphi_dt = y

    rs = 2 * G * M
    sigma = (dr_dt**2 + r**2 * dphi_dt**2) * (1 - 2*rs / r)

    dr_dtau = - np.sqrt(E^2 - sigma * (1 - 2*rs / r) +L**2 / (2*r**2) + G * M * L**2 / r**3)
    dphi_dtau = L / r**2

    return [dr_dt, dphi_dt, dr_dtau, dphi_dtau]

# initial conditions
r0 = 10
phi0 = 0
dr_dt0 = 0
dphi_dt0 = 1 / r0**2
y0 = [r0, phi0, dr_dt0, dphi_dt0]

# time span
t_span = np.linspace(0, 100, 1000)

# constants
G = 1
M = 1

# solve the differential equations
sol = odeint(schwarzschild_orbit, y0, t_span, args=(G, M))

# extract the results
r = sol[:, 0]
phi = sol[:, 1]

# %%
plt.plot(r * np.cos(phi), r * np.sin(phi))
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint

# Constants
G = 6.6743e-11   # gravitational constant
c = 299792458    # speed of light
M = 1.989e30     # mass of the black hole in kg
rs = 2*G*M/c**2  # Schwarzschild radius

# Initial conditions
r0 = 4*rs        # initial radial distance from the black hole
v0 = 0           # initial radial velocity
phi0 = 0         # initial angle phi
theta0 = np.pi/2 # initial angle theta
t0 = 0           # initial time
tau0 = 0         # initial proper time

E = 1
L = 1

# Radial equation of motion
def radial_eqn(r, L):
    drdtau = E

    d2rdtau2 = -G*M / r**2 + L**2 / r**3 - 3* G * M * L ** 2/ r**4
    return [drdtau, d2rdtau2]

# Angular equations of motion
def angular_eqns(y, tau):
    r, v, theta, dphidtau = y
    dt_dtau = E/(1-rs/r)
    d2thetadtau2 = -G*M/(r**3)*(1-rs/r)*np.sin(theta)
    d2phidtau2 = -2*v/(r*(1-rs/r))*dphidtau
    return [v/(1-rs/r), d2thetadtau2, dphidtau, d2phidtau2]

# Initial values for the angular equations of motion
v0 = 0
dphidtau0 = 0
y0 = [r0, v0, theta0, dphidtau0]

# Time grid
t = np.linspace(t0, 1, 100) # end time = 1000 seconds

# Solve the radial equation of motion
sol_radial = odeint(radial_eqn, [r0, v0], [tau0, 2*np.sqrt(3)*M*G], rtol=1e-3, atol=1e-3)

# Solve the angular equations of motion using the solution of the radial equation
sol_angular = odeint(angular_eqns, y0, sol_radial[:, 0], rtol=1e-3, atol=1e-3)

# Extract the radial distance and angles as a function of time
r = sol_radial[:, 0]
theta = sol_angular[:, 2]
phi = sol_angular[:, 3]

# Plot the trajectory
import matplotlib.pyplot as plt

x = r*np.sin(theta)*np.cos(phi)
y = r*np.sin(theta)*np.sin(phi)
z = r*np.cos(theta)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(x, y, z, linewidth=0.5)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

# %%
import numpy as np
from scipy.integrate import odeint

# Constants
G = 6.6743e-11   # gravitational constant
c = 299792458    # speed of light
M = 1.989e30     # mass of the black hole in kg
rs = 2*G*M/c**2  # Schwarzschild radius

# Initial conditions
r0 = 4*rs        # initial radial distance from the black hole
v0 = 0           # initial radial velocity
phi0 = 0         # initial angle phi
theta0 = np.pi/2 # initial angle theta
t0 = 0           # initial time
tau0 = 0         # initial proper time

# Radial equation of motion
def radial_eqn(r, tau):
    drdtau = v
    dt_dtau = E / (1-rs/r)
    d2rdtau2 = -G*M/(r**2*(1-rs/r))*(1-3*rs/(2*r))*(dt_dtau**2) + \
               1/2*(1-rs/r)**(-1)*(1+rs/(2*r))*r**2*d2thetadtau2 + \
               1/2*(1-rs/r)**(-1)*(1+rs/(2*r))*r**2*np.sin(theta)**2*d2phidtau2
    return [drdtau, d2rdtau2]

# Angular equations of motion
def angular_eqns(y, tau):
    r, v, theta, dphidtau = y
    dt_dtau = v/(1-rs/r)
    d2thetadtau2 = -G*M/(r**3)*(1-rs/r)*np.sin(theta)
    d2phidtau2 = -2*v/(r*(1-rs/r))*dphidtau
    return [v/(1-rs/r), d2thetadtau2, dphidtau, d2phidtau2]

# Initial values for the angular equations of motion
v0 = 0
dphidtau0 = 0
y0 = [r0, v0, theta0, dphidtau0]

# Time grid
t = np.linspace(t0, 1000, 10000) # end time = 1000 seconds

# Solve the radial equation of motion
sol_radial = odeint(radial_eqn, [r0, v0], [tau0, 1000], rtol=1e-10, atol=1e-10)

# Solve the angular equations of motion using the solution of the radial equation
sol_angular = odeint(angular_eqns, y0, sol_radial[:, 0], rtol=1e-10, atol=1e-10)

# Extract the radial distance and angles as a function of time
r = sol_radial[:, 0]
theta = sol_angular[:, 2]
phi = sol_angular[:, 3]

# Plot the trajectory
import matplotlib.pyplot as plt

x = r*np.sin(theta)*np.cos(phi)
y = r*np.sin(theta)*np.sin(phi)
z = r*np.cos(theta)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(x, y, z, linewidth=0.5)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Define the parameters
M = 1.0
L = 2 * G * M * np.sqrt(3)

# Define the function that returns the derivative of r with respect to phi
def func(r, phi):
    u = r[0]
    dudphi = r[1]
    d2udphi2 = 3*(M/L)**2 * u**2 - u + 1
    return [dudphi, d2udphi2]

# Define the initial conditions
u0 = 1.0
dudphi0 = 0.01
r0 = [u0, dudphi0]

# Define the range of phi values for which to solve the equation
phi_vals = np.linspace(0, 2*np.pi/100, 1000)

# Use scipy's odeint function to solve the equation for r as a function of phi
sol = odeint(func, r0, phi_vals)

# Extract the solution for u (the radial distance)
u_vals = sol[:,0]

r_vals = 1 / u_vals

# Convert u values to Cartesian coordinates x and y
x_vals = u_vals*np.cos(phi_vals)
y_vals = u_vals*np.sin(phi_vals)

# Plot the resulting orbit
plt.plot(x_vals, y_vals)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Orbit')
plt.show()
